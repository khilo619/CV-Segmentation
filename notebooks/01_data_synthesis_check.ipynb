# %% [markdown]
# # Notebook 01: Data Exploration & Anti-Leakage Synthesis Audit
# **Assigned:** Engineer 3
#
# ### Goals:
# 1. Load raw open-source resumes from Kaggle / Hugging Face.
# 2. Inspect page counts, font variations, and metadata dictionaries.
# 3. Verify that pikepdf / Ghostscript concatenation strips `/CreationDate` and `/Producer`.
# 4. Sample length distributions: 45% (1-page), 42% (2-page), 10% (3-page), 3% (4+ page).

# %%
print("Environment initialized for data synthesis audit.")
