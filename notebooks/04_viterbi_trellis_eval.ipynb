# %% [markdown]
# # Notebook 04: Viterbi HMM Trellis Optimization & Sequence Decoding
# **Assigned:** Engineer 3 & Engineer 1
#
# ### Goals:
# 1. Test Viterbi dynamic programming trellis on ambiguous stream boundaries.
# 2. Verify elimination of illegal transitions (e.g., START -> PAGE_3).
# 3. Benchmark decoding latency (<1 ms for 500 pages).

# %%
import yaml

with open("configs/hmm_priors.yaml", "r") as f:
    hmm_cfg = yaml.safe_load(f)
print("HMM States:", hmm_cfg["states"])
