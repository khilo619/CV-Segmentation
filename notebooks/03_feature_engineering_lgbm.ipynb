# %% [markdown]
# # Notebook 03: Feature Engineering, SHAP Importance & LightGBM Tuning
# **Assigned:** Engineer 3 & Engineer 2
#
# ### Goals:
# 1. Extract 36-dimensional pairwise feature vectors from synthetic streams.
# 2. Train baseline LightGBM pairwise binary classifier.
# 3. Run SHAP summary plots to prune redundant features.
# 4. Perform Optuna hyperparameter optimization.

# %%
import lightgbm as lgb

print("LightGBM version:", lgb.__version__)
