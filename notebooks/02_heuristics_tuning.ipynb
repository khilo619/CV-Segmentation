# %% [markdown]
# # Notebook 02: Heuristics Prototyping & Parameter Tuning
# **Assigned:** Engineer 2
#
# ### Goals:
# 1. Test PII regex and international phone parsing on sample headers.
# 2. Visualize font dominance distribution (Title Font / Median Font).
# 3. Prototype header/footer pagination parser (`Page X of Y`, `Page 2`).
# 4. Test syntactic fracture detection across page splits.

# %%
import yaml
from pathlib import Path

with open("configs/heuristics.yaml", "r") as f:
    heuristics_cfg = yaml.safe_load(f)
print("Loaded heuristics config:", heuristics_cfg.keys())
